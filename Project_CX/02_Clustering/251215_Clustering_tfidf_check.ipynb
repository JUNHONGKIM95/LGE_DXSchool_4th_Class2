# %%
import pandas as pd

# %%
actor_num = 2
input_path = f'./results/yj_251215/cluster{actor_num}_tf_idf.csv'

# %%
df = pd.read_csv(input_path)
df = df[['tfidf_word', 'tfidf']]
df.head(20)
# Out:
#    tfidf_word     tfidf
# 0          맛집  0.415085
# 1          맛있  0.381828
# 2          나오  0.264806
# 3          고기  0.257916
# 4          메뉴  0.151852
# 5          주문  0.144691
# 6          음식  0.140893
# 7          펜션  0.131725
# 8          식사  0.130043
# 9          생각  0.128578
# 10         즐기  0.115286
# 11         느끼  0.114961
# 12         정도  0.100692
# 13         요리  0.099390
# 14         식당  0.098956
# 15        들어가  0.093857
# 16         보이  0.092555
# 17         친구  0.091470
# 18         가족  0.089788
# 19         갈비  0.085068
